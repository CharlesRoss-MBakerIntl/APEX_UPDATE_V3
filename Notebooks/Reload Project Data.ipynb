# %%
import requests
import pandas as pd
import datetime
import pytz
import json

from agol_restapi_tools import create_log_ids
from agol_restapi_tools import agol_date_convert_akt
from agol_restapi_tools import columns_compare
from agol_restapi_tools import pd_to_attributes_list
from agol_restapi_tools import token_generation
from agol_restapi_tools import agol_table_to_pd
from agol_restapi_tools import add_new_logs
from agol_restapi_tools import oid_field
from agol_restapi_tools import locate_objectid

token = token_generation("AKDOT_COMMUNICATIONS", "Skisnowbird1")

# %% [markdown]
# ### Pull Master Project Data

# %%
projects_url = "https://services.arcgis.com/r4A0V7UzH9fcLVvv/arcgis/rest/services/CY2023_Project_Polygons_notcleaned/FeatureServer"
projects = agol_table_to_pd(projects_url, 0, token, drop_objectids="Y")

# %% [markdown]
# ### Re-Load Start and End Points

# %%
starts_url = "https://services.arcgis.com/r4A0V7UzH9fcLVvv/arcgis/rest/services/Start_Points/FeatureServer"
ends_url = "https://services.arcgis.com/r4A0V7UzH9fcLVvv/arcgis/rest/services/End_Points/FeatureServer"

# %%
# Clear Starts Points from Layer
delete_url = f"{starts_url}/0/deleteFeatures"

params = {
    'f':'json',
    'where':'1=1',
    'token':token
}

response = requests.post(delete_url, params)

# %%
# Clear Ends Points from Layer
delete_url = f"{ends_url}/0/deleteFeatures"

params = {
    'f':'json',
    'where':'1=1',
    'token':token
}

response = requests.post(delete_url, params)

# %%
counter = 0

# Iterate Through Projects UIDS, Pull Geometry, Add Entry to Start and End with Lat, Long and Project Data
for index, row in projects.iterrows():

    uid = row["Unique_ID"]
    name = row['Project_Name']
    iris = row['IRIS_Number']

    if name == None:
        name = ""
        
    if iris == None:
        iris = ""

    query = f"{projects_url}/0/query"

    params = {
        'where': f'Unique_ID={uid}',
        'outFields': '*',
        'returnGeometry': 'true',
        'f': 'geojson',
        'token':token
    }

    response = requests.get(query, params)

    # Extract the geometry from the response
    data = response.json()
    geometry = [feature['geometry'] for feature in data['features']]

    if geometry[0]['type'] == "MultiPolygon":
        geometry[0]['coordinates'] = geometry[0]['coordinates'][0]

    #Extract Min and Max Lat,Lng
    min = geometry[0]['coordinates'][0][0]
    min_lat= min[1]
    min_lng = min[0]

    max = geometry[0]['coordinates'][0][int(len(geometry[0]['coordinates'][0])/2)]
    max_lat= max[1]
    max_lng = max[0]


   #Create Start and End Payloads
    start_geo_payload =  [
        {
            "geometry": {
            "x": min_lng,
            "y": min_lat,
                'spatialReference': {
                'wkid': 4326 }
            },
            "attributes": {
            "UID": uid,
            "Project_Name":name,
            "IRIS_Number":iris
            } 
        } 
        ]

    end_geo_payload =  [
        {
            "geometry": {
            "x": max_lng,
            "y": max_lat,
                'spatialReference': {
                'wkid': 4326 }
            },
            "attributes": {
            "UID": uid,
            "Project_Name":name,
            "IRIS_Number":iris
            } 
        } 
        ]
    

    #Load Start to Layer
    start_update_url = f'{starts_url}/0/applyEdits'

    start_update_params = {
        'f':'json',
        'token':token,
        'adds':f'{start_geo_payload}'
    }

    start_response = requests.patch(url = start_update_url, params = start_update_params)
    print(start_response.json())


    #Load End to Layer
    end_update_url = f'{ends_url}/0/applyEdits'

    end_update_params = {
        'f':'json',
        'token':token,
        'adds':f'{end_geo_payload}'
    }

    end_response = requests.patch(url = end_update_url, params = end_update_params)
    print(end_response.json())

    counter += 1

# %% [markdown]
# ### Re-Load the Alaksa 511 Management Table

# %%
management_url = "https://services.arcgis.com/r4A0V7UzH9fcLVvv/arcgis/rest/services/AK_511_Management/FeatureServer"

# %%
# Clear Starts Points from Layer
delete_url = f"{management_url}/0/deleteFeatures"

params = {
    'f':'json',
    'where':'1=1',
    'token':token
}

response = requests.post(delete_url, params)

# %%
#Grab Subset of Project Data Needed for Project Input
project_sel = projects[[
    "Unique_ID",
    "Project_Name",
    "IRIS_Number",
    "Route_ID",
    "Route_Name",
    "Federal_Project_Number",
    "STIP_ID",
    "DOT_PF_Region",
    "Borough_CensusArea",
    "State_House_District",
    "State_Senate_District",
    "Project_Description",
    "Project_Purpose",
    "Project_Website",
    "Project_Priority_Area",
    "Project_Engineer_Email",
    "Design_Engineer",
    "Design_Engineer_Phone",
    "Construction_Engineer",
    "Construction_Engineer_Phone",
    "Contract_Value",
    "Anticipated_Start",
    "Anticipated_End",
    "Funding_Type",
    "Project_Practice",
    "Project_Location",
    "Project_Limit",
    "Project_Impact",
    "Construction_Description",
    "Longitude",
    "Latitude"
]]


#Rename Unique ID Field
project_sel.rename(columns = {"Unique_ID":"UID"}, inplace = True)

#Projects Fill Missing Values
project_sel.fillna("", inplace = True)

#Replace Empty String Characters
project_sel.replace('\xa0', '', regex=True, inplace = True)



#Iterate Through Project Select Entries, Create Entry Row and Add to Feature Layer
for index, row in project_sel.iterrows():
    df = pd.DataFrame(row).T
    entry = pd_to_attributes_list(df)

    applyEdits = f"{management_url}/0/applyEdits"

    params = {
        "f":'json',
        "token":token,
        "adds":f'{entry}'
        }

    print(requests.post(applyEdits, params).json())
# Out:
# {'addResults': [{'objectId': 588, 'uniqueId': 588, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 589, 'uniqueId': 589, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 590, 'uniqueId': 590, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 591, 'uniqueId': 591, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 592, 'uniqueId': 592, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 593, 'uniqueId': 593, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 594, 'uniqueId': 594, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 595, 'uniqueId': 595, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 596, 'uniqueId': 596, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 597, 'uniqueId': 597, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 598, 'uniqueId': 598, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 599, 'uniqueId': 599, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 600, 'uniqueId': 600, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 601, 'uniqueId': 601, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 602, 'uniqueId': 602, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 603, 'uniqueId': 603, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 604, 'uniqueId': 604, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 605, 'uniqueId': 605, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 606, 'uniqueId': 606, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 607, 'uniqueId': 607, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 608, 'uniqueId': 608, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 609, 'uniqueId': 609, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 610, 'uniqueId': 610, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 611, 'uniqueId': 611, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 612, 'uniqueId': 612, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 613, 'uniqueId': 613, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 614, 'uniqueId': 614, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 615, 'uniqueId': 615, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 616, 'uniqueId': 616, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 617, 'uniqueId': 617, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 618, 'uniqueId': 618, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 619, 'uniqueId': 619, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 620, 'uniqueId': 620, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 621, 'uniqueId': 621, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 622, 'uniqueId': 622, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 623, 'uniqueId': 623, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 624, 'uniqueId': 624, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 625, 'uniqueId': 625, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 626, 'uniqueId': 626, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 627, 'uniqueId': 627, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 628, 'uniqueId': 628, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 629, 'uniqueId': 629, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 630, 'uniqueId': 630, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 631, 'uniqueId': 631, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 632, 'uniqueId': 632, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 633, 'uniqueId': 633, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 634, 'uniqueId': 634, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 635, 'uniqueId': 635, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 636, 'uniqueId': 636, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId': 637, 'uniqueId': 637, 'globalId': None, 'success': True}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'objectId':